# %%
import keras
import numpy as np
from keras.models import Sequential
import keras.callbacks as cb
from keras.datasets import mnist


from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()




model.add(Dense(8, activation = "tanh",input_shape=(2,)))# 1 is the size of the first hidden layer
model.add(Dense(4, activation = "tanh"))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss="mse", optimizer='SGD',metrics=["accuracy"])
model.summary()
#SVG(model_to_dot(model).create(prog='dot', format='svg')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 8)                 24
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 5
# ...
# Total params: 65
# Trainable params: 65
# Non-trainable params: 0
# _________________________________________________________________

# %%
input = np.array([[0,0],[0,1],[1,0],[1,1]])
input = pd.DataFrame(input)
and_gate = np.array([[0],[0],[0],[1]])
and_gate = pd.DataFrame(and_gate)
or_gate = np.array([[0],[1],[1],[1]])
xor_gate = np.array([[0],[1],[1],[0]]) 






print(and_gate)
# Out:
#    0
# 0  0
# 1  0
# 2  0
# 3  1

# %%
class LossHistory(cb.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        batch_loss = logs.get('loss')
        self.losses.append(batch_loss)

        
        
history = LossHistory()
model.fit(input,and_gate,epochs = 100,verbose=1, callbacks = [history])
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 497us/step - loss: 0.2116 - acc: 0.7500
# Epoch 2/100
# 4/4 [==============================] - 0s 250us/step - loss: 0.2113 - acc: 0.7500
# Epoch 3/100
# 4/4 [==============================] - 0s 507us/step - loss: 0.2110 - acc: 0.7500
# Epoch 4/100
# 4/4 [==============================] - 0s 250us/step - loss: 0.2107 - acc: 0.7500
# Epoch 5/100
# 4/4 [==============================] - 0s 250us/step - loss: 0.2104 - acc: 0.7500
# Epoch 6/100
# 4/4 [==============================] - 0s 0us/step - loss: 0.2101 - acc: 0.7500
# Epoch 7/100
# 4/4 [==============================] - 0s 250us/step - loss: 0.2098 - acc: 0.7500
# Epoch 8/100
# 4/4 [==============================] - 0s 250us/step - loss: 0.2095 - acc: 0.7500
# Epoch 9/100
# 4/4 [==============================] - 0s 251us/step - loss: 0.2092 - acc: 0.7500
# Epoch 10/100
# 4/4 [==============================] - 0s 500us/step - loss: 0.2089 - acc: 0.7500
# Epoch 11/100
# ...

# %%
model.predict(np.array([[0,0]]))
# Out:
# array([[-0.15464905]], dtype=float32)

# %%
history = LossHistory()
model.fit(input,xor_gate,epochs = 1000,verbose=1, callbacks = [history])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 743us/step - loss: 0.0522 - acc: 1.0000
# Epoch 2/1000
# 4/4 [==============================] - 0s 750us/step - loss: 0.0521 - acc: 1.0000
# Epoch 3/1000
# 4/4 [==============================] - 0s 500us/step - loss: 0.0519 - acc: 1.0000
# Epoch 4/1000
# 4/4 [==============================] - 0s 757us/step - loss: 0.0518 - acc: 1.0000
# Epoch 5/1000
# 4/4 [==============================] - 0s 493us/step - loss: 0.0516 - acc: 1.0000
# Epoch 6/1000
# 4/4 [==============================] - 0s 500us/step - loss: 0.0515 - acc: 1.0000
# Epoch 7/1000
# 4/4 [==============================] - 0s 500us/step - loss: 0.0513 - acc: 1.0000
# Epoch 8/1000
# 4/4 [==============================] - 0s 511us/step - loss: 0.0512 - acc: 1.0000
# Epoch 9/1000
# 4/4 [==============================] - 0s 750us/step - loss: 0.0510 - acc: 1.0000
# Epoch 10/1000
# 4/4 [==============================] - 0s 749us/step - loss: 0.0509 - acc: 1.0000
# ...

# %%
model.predict(np.array([[0,0]]))
# Out:
# array([[0.10071396]], dtype=float32)
